# %%
import pandas as pd

# %%
fifa = pd.read_csv('fifa_eda.csv', sep=',', skiprows=None)
fifa.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# ...

# %%
fifa.head(20)
# Out:
#         ID               Name  Age Nationality  Overall  Potential  \
# 0   158023           L. Messi   31   Argentina       94         94
# 1    20801  Cristiano Ronaldo   33    Portugal       94         94
# 2   190871          Neymar Jr   26      Brazil       92         93
# 3   193080             De Gea   27       Spain       91         93
# 4   192985       K. De Bruyne   27     Belgium       91         92
# 5   183277          E. Hazard   27     Belgium       91         91
# 6   177003          L. Modrić   32     Croatia       91         91
# 7   176580          L. Suárez   31     Uruguay       91         91
# 8   155862       Sergio Ramos   32       Spain       91         91
# 9   200389           J. Oblak   25    Slovenia       90         93
# 10  188545     R. Lewandowski   29      Poland       90         90
# 11  182521           T. Kroos   28     Germany       90         90
# 12  182493           D. Godín   32     Uruguay       90         90
# ...

# %%
fifa.tail(5)
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                    Club  Value  Wage Preferred Foot  International Reputation  \
# 18202   Crewe Alexandra   60.0   1.0          Right                       1.0
# 18203    Trelleborgs FF   60.0   1.0          Right                       1.0
# 18204  Cambridge United   60.0   1.0          Right                       1.0
# 18205   Tranmere Rovers   60.0   1.0          Right                       1.0
# 18206   Tranmere Rovers   60.0   1.0          Right                       1.0
#
# ...

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Nationality               18207 non-null  object
#  4   Overall                   18207 non-null  int64
#  5   Potential                 18207 non-null  int64
#  6   Club                      17966 non-null  object
#  7   Value                     17955 non-null  float64
#  8   Wage                      18207 non-null  float64
#  9   Preferred Foot            18207 non-null  object
#  10  International Reputation  18159 non-null  float64
#  11  Skill Moves               18159 non-null  float64
#  12  Position                  18207 non-null  object
# ...

# %%
fifa.shape
# Out:
# (18207, 18)

# %%
fifa.shape[0]
# Out:
# 18207

# %%
fifa.shape[1]
# Out:
# 18

# %%
print(f'Temos {fifa.shape[0]} linhas e {fifa.shape[1]} colunas')
# Out:
# Temos 18207 linhas e 18 colunas

# %%
fifa.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club',
#        'Value', 'Wage', 'Preferred Foot', 'International Reputation',
#        'Skill Moves', 'Position', 'Joined', 'Contract Valid Until', 'Height',
#        'Weight', 'Release Clause'],
#       dtype='object')

# %%
fifa.columns[0:2]
# Out:
# Index(['ID', 'Name'], dtype='object')

# %%
fifa.index
# Out:
# RangeIndex(start=0, stop=18207, step=1)

# %%
pd.set_option('max_colwidth',20)
pd.set_option('max_rows',100)
pd.set_option('max_columns',18)

pd.get_option('max_colwidth') #Descobre a largura das colunas
# Out:
# 20

# %%
print(fifa.head(50))
# Out:
#         ID               Name  Age Nationality  Overall  Potential  \
# 0   158023           L. Messi   31   Argentina       94         94
# 1    20801  Cristiano Ronaldo   33    Portugal       94         94
# 2   190871          Neymar Jr   26      Brazil       92         93
# 3   193080             De Gea   27       Spain       91         93
# 4   192985       K. De Bruyne   27     Belgium       91         92
# 5   183277          E. Hazard   27     Belgium       91         91
# 6   177003          L. Modrić   32     Croatia       91         91
# 7   176580          L. Suárez   31     Uruguay       91         91
# 8   155862       Sergio Ramos   32       Spain       91         91
# 9   200389           J. Oblak   25    Slovenia       90         93
# 10  188545     R. Lewandowski   29      Poland       90         90
# 11  182521           T. Kroos   28     Germany       90         90
# 12  182493           D. Godín   32     Uruguay       90         90
# ...

# %%
def low_values_red(value):
    color = 'red' if value < 93 else 'black'
    return 'color:%s'%color

fifa[['Overall', 'Potential']].head(10).style.applymap(low_values_red)
# Out:
# <style  type="text/css" >
# #T_65481_row0_col0,#T_65481_row0_col1,#T_65481_row1_col0,#T_65481_row1_col1,#T_65481_row2_col1,#T_65481_row3_col1,#T_65481_row9_col1{
#             color: black;
#         }#T_65481_row2_col0,#T_65481_row3_col0,#T_65481_row4_col0,#T_65481_row4_col1,#T_65481_row5_col0,#T_65481_row5_col1,#T_65481_row6_col0,#T_65481_row6_col1,#T_65481_row7_col0,#T_65481_row7_col1,#T_65481_row8_col0,#T_65481_row8_col1,#T_65481_row9_col0{
#             color: red;
#         }</style><table id="T_65481_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Overall</th>        <th class="col_heading level0 col1" >Potential</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_65481_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_65481_row0_col0" class="data row0 col0" >94</td>
# ...

# %%
fifa.head(20).style.applymap(low_values_red, subset=['Overall', 'Potential'])
# Out:
# <style  type="text/css" >
# #T_ac225_row0_col4,#T_ac225_row0_col5,#T_ac225_row1_col4,#T_ac225_row1_col5,#T_ac225_row2_col5,#T_ac225_row3_col5,#T_ac225_row9_col5,#T_ac225_row15_col5{
#             color: black;
#         }#T_ac225_row2_col4,#T_ac225_row3_col4,#T_ac225_row4_col4,#T_ac225_row4_col5,#T_ac225_row5_col4,#T_ac225_row5_col5,#T_ac225_row6_col4,#T_ac225_row6_col5,#T_ac225_row7_col4,#T_ac225_row7_col5,#T_ac225_row8_col4,#T_ac225_row8_col5,#T_ac225_row9_col4,#T_ac225_row10_col4,#T_ac225_row10_col5,#T_ac225_row11_col4,#T_ac225_row11_col5,#T_ac225_row12_col4,#T_ac225_row12_col5,#T_ac225_row13_col4,#T_ac225_row13_col5,#T_ac225_row14_col4,#T_ac225_row14_col5,#T_ac225_row15_col4,#T_ac225_row16_col4,#T_ac225_row16_col5,#T_ac225_row17_col4,#T_ac225_row17_col5,#T_ac225_row18_col4,#T_ac225_row18_col5,#T_ac225_row19_col4,#T_ac225_row19_col5{
#             color: red;
# ...

# %%
fifa.loc[1]
# Out:
# ID                                      20801
# Name                        Cristiano Ronaldo
# Age                                        33
# Nationality                          Portugal
# Overall                                    94
# Potential                                  94
# Club                                 Juventus
# Value                                 77000.0
# Wage                                    405.0
# Preferred Foot                          Right
# International Reputation                  5.0
# Skill Moves                               5.0
# Position                                   ST
# Joined                                   2018
# Contract Valid Until               2022-01-01
# Height                               6.166667
# Weight                                  183.0
# Release Clause                       127100.0
# Name: 1, dtype: object

# %%
fifa.loc[0:5]
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
# 5  183277          E. Hazard   27     Belgium       91         91
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
# 5              Chelsea   93000.0  340.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# ...

# %%
fifa.loc[1:5, 'Age'] #Posição da linha e nome da coluna
# Out:
# 1    33
# 2    26
# 3    27
# 4    27
# 5    27
# Name: Age, dtype: int64

# %%
fifa.iloc[0:5,0:2] #Posição da linha e Posição da coluna
# Out:
#        ID               Name
# 0  158023           L. Messi
# 1   20801  Cristiano Ronaldo
# 2  190871          Neymar Jr
# 3  193080             De Gea
# 4  192985       K. De Bruyne

# %%
fifa[0:6] #Filtro direto, somente linha
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
# 5  183277          E. Hazard   27     Belgium       91         91
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
# 5              Chelsea   93000.0  340.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# ...

# %%
df = fifa

# %%
df.loc[(df['Age']>=25) & (df['Overall']>=90)]
# Out:
#         ID               Name  Age Nationality  Overall  Potential  \
# 0   158023           L. Messi   31   Argentina       94         94
# 1    20801  Cristiano Ronaldo   33    Portugal       94         94
# 2   190871          Neymar Jr   26      Brazil       92         93
# 3   193080             De Gea   27       Spain       91         93
# 4   192985       K. De Bruyne   27     Belgium       91         92
# 5   183277          E. Hazard   27     Belgium       91         91
# 6   177003          L. Modrić   32     Croatia       91         91
# 7   176580          L. Suárez   31     Uruguay       91         91
# 8   155862       Sergio Ramos   32       Spain       91         91
# 9   200389           J. Oblak   25    Slovenia       90         93
# 10  188545     R. Lewandowski   29      Poland       90         90
# 11  182521           T. Kroos   28     Germany       90         90
# 12  182493           D. Godín   32     Uruguay       90         90
# ...

# %%
df.query('Age > 30').head(5)
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 6  177003          L. Modrić   32     Croatia       91         91
# 7  176580          L. Suárez   31     Uruguay       91         91
# 8  155862       Sergio Ramos   32       Spain       91         91
#
#            Club     Value   Wage Preferred Foot  International Reputation  \
# 0  FC Barcelona  110500.0  565.0           Left                  5.0
# 1      Juventus   77000.0  405.0          Right                  5.0
# 6   Real Madrid   67000.0  420.0          Right                  4.0
# 7  FC Barcelona   80000.0  455.0          Right                  5.0
# 8   Real Madrid   51000.0  380.0          Right                  4.0
#
#    Skill Moves Position  Joined Contract Valid Until    Height  Weight  \
# 0          4.0       RF    2004           2021-01-01  5.583333   159.0
# ...

# %%
df[df['International Reputation']==df['Skill Moves']]
# Out:
#            ID               Name  Age Nationality  Overall  Potential  \
# 1       20801  Cristiano Ronaldo   33    Portugal       94         94
# 2      190871          Neymar Jr   26      Brazil       92         93
# 4      192985       K. De Bruyne   27     Belgium       91         92
# 5      183277          E. Hazard   27     Belgium       91         91
# 6      177003          L. Modrić   32     Croatia       91         91
# ...       ...                ...  ...         ...      ...        ...
# 18178  243158       L. Wahlstedt   18      Sweden       48         65
# 18180  221669           M. Hurst   22    Scotland       48         58
# 18183   53748      K. Pilkington   44     England       48         48
# 18194  245862           J. Milli   18       Italy       47         65
# 18198  242844         J. Livesey   18     England       47         70
#
#                       Club     Value   Wage Preferred Foot  \
# 1                 Juventus   77000.0  405.0          Right
# ...

# %%
df.filter(['Age','ID', 'Name'])
# Out:
#        Age      ID                Name
# 0       31  158023            L. Messi
# 1       33   20801   Cristiano Ronaldo
# 2       26  190871           Neymar Jr
# 3       27  193080              De Gea
# 4       27  192985        K. De Bruyne
# ...    ...     ...                 ...
# 18202   19  238813        J. Lundstram
# 18203   19  243165  N. Christoffersson
# 18204   16  241638           B. Worman
# 18205   17  246268      D. Walker-Rice
# 18206   16  246269           G. Nugent
#
# [18207 rows x 3 columns]

# %%
media = df['Overall'].median()
print(media)
df.query('Overall > @media')
# Out:
# 66.0
#           ID               Name  Age Nationality  Overall  Potential  \
# 0     158023           L. Messi   31   Argentina       94         94
# 1      20801  Cristiano Ronaldo   33    Portugal       94         94
# 2     190871          Neymar Jr   26      Brazil       92         93
# 3     193080             De Gea   27       Spain       91         93
# 4     192985       K. De Bruyne   27     Belgium       91         92
# ...      ...                ...  ...         ...      ...        ...
# 8759  224509           U. Rivas   22      Mexico       67         73
# 8760  214014        C. Lizarazo   27    Colombia       67         67
# 8761  104702         D. Braaten   36      Norway       67         67
# 8762  229631               Lazo   22       Spain       67         75
# 8763  246015            L. Mago   23   Venezuela       67         73
#
#                      Club     Value   Wage Preferred Foot  \
# 0            FC Barcelona  110500.0  565.0           Left
# ...

# %%
cam = df[df['Nationality'].isin(['Brazil', 'Argentina', 'Mexico', 'Spain', 'Germany'])]
cam.head()
# Out:
#         ID          Name  Age Nationality  Overall  Potential  \
# 0   158023      L. Messi   31   Argentina       94         94
# 2   190871     Neymar Jr   26      Brazil       92         93
# 3   193080        De Gea   27       Spain       91         93
# 8   155862  Sergio Ramos   32       Spain       91         91
# 11  182521      T. Kroos   28     Germany       90         90
#
#                    Club     Value   Wage Preferred Foot  \
# 0          FC Barcelona  110500.0  565.0           Left
# 2   Paris Saint-Germain  118500.0  290.0          Right
# 3     Manchester United   72000.0  260.0          Right
# 8           Real Madrid   51000.0  380.0          Right
# 11          Real Madrid   76500.0  355.0          Right
#
#     International Reputation  Skill Moves Position  Joined  \
# 0                   5.0               4.0       RF    2004
# 2                   5.0               5.0       LW    2017
# 3                   4.0               1.0       GK    2011
# ...

# %%
no_cam = df[-df['Nationality'].isin(['Brazil', 'Argentina', 'Mexico', 'Spain', 'Germany'])]
no_cam.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 4  192985       K. De Bruyne   27     Belgium       91         92
# 5  183277          E. Hazard   27     Belgium       91         91
# 6  177003          L. Modrić   32     Croatia       91         91
# 7  176580          L. Suárez   31     Uruguay       91         91
#
#               Club     Value   Wage Preferred Foot  International Reputation  \
# 1         Juventus   77000.0  405.0          Right                  5.0
# 4  Manchester City  102000.0  355.0          Right                  4.0
# 5          Chelsea   93000.0  340.0          Right                  4.0
# 6      Real Madrid   67000.0  420.0          Right                  4.0
# 7     FC Barcelona   80000.0  455.0          Right                  5.0
#
#    Skill Moves Position  Joined Contract Valid Until    Height  Weight  \
# ...

# %%
#Somente os valores que são numericos

numeric = ['int16', 'int32', 'int64', 'float16', 'float32','float64']
df_numerico = df.select_dtypes(numeric)
df_numerico.head()
# Out:
#        ID  Age  Overall  Potential     Value   Wage  International Reputation  \
# 0  158023   31       94         94  110500.0  565.0                  5.0
# 1   20801   33       94         94   77000.0  405.0                  5.0
# 2  190871   26       92         93  118500.0  290.0                  5.0
# 3  193080   27       91         93   72000.0  260.0                  4.0
# 4  192985   27       91         92  102000.0  355.0                  4.0
#
#    Skill Moves  Joined    Height  Weight  Release Clause
# 0          4.0    2004  5.583333   159.0        226500.0
# 1          5.0    2018  6.166667   183.0        127100.0
# 2          5.0    2017  5.750000   150.0        228100.0
# 3          1.0    2011  6.333333   168.0        138600.0
# 4          4.0    2015  5.916667   154.0        196400.0

# %%
#Somente valores NÃO numericos
numeric = ['int16', 'int32', 'int64', 'float16', 'float32','float64']
df_numerico = df.select_dtypes(exclude = numeric)
df_numerico.head()
# Out:
#                 Name Nationality                 Club Preferred Foot Position  \
# 0           L. Messi   Argentina         FC Barcelona           Left       RF
# 1  Cristiano Ronaldo    Portugal             Juventus          Right       ST
# 2          Neymar Jr      Brazil  Paris Saint-Germain          Right       LW
# 3             De Gea       Spain    Manchester United          Right       GK
# 4       K. De Bruyne     Belgium      Manchester City          Right      RCM
#
#   Contract Valid Until
# 0           2021-01-01
# 1           2022-01-01
# 2           2022-01-01
# 3           2020-01-01
# 4           2023-01-01

# %%
df.sort_values(by='Overall', ascending=False).head(10)
# Out:
#         ID               Name  Age Nationality  Overall  Potential  \
# 0   158023           L. Messi   31   Argentina       94         94
# 1    20801  Cristiano Ronaldo   33    Portugal       94         94
# 2   190871          Neymar Jr   26      Brazil       92         93
# 3   193080             De Gea   27       Spain       91         93
# 4   192985       K. De Bruyne   27     Belgium       91         92
# 5   183277          E. Hazard   27     Belgium       91         91
# 6   177003          L. Modrić   32     Croatia       91         91
# 7   176580          L. Suárez   31     Uruguay       91         91
# 8   155862       Sergio Ramos   32       Spain       91         91
# 12  182493           D. Godín   32     Uruguay       90         90
#
#                    Club     Value   Wage Preferred Foot  \
# 0          FC Barcelona  110500.0  565.0           Left
# 1              Juventus   77000.0  405.0          Right
# 2   Paris Saint-Germain  118500.0  290.0          Right
# ...

# %%
df.drop_duplicates()
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
df.describe()
# Out:
#                   ID           Age       Overall     Potential          Value  \
# count   18207.000000  18207.000000  18207.000000  18207.000000   17955.000000
# mean   214298.338606     25.122206     66.238699     71.307299    2444.530214
# std     29965.244204      4.669943      6.908930      6.136496    5626.715434
# min        16.000000     16.000000     46.000000     48.000000      10.000000
# 25%    200315.500000     21.000000     62.000000     67.000000     325.000000
# 50%    221759.000000     25.000000     66.000000     71.000000     700.000000
# 75%    236529.500000     28.000000     71.000000     75.000000    2100.000000
# max    246620.000000     45.000000     94.000000     95.000000  118500.000000
#
#                Wage  International Reputation   Skill Moves        Joined  \
# count  18207.000000         18159.000000       18159.000000  18207.000000
# mean       9.731312             1.113222           2.361308   2016.420607
# ...

# %%
df['Age'].describe([0.1, 0.2, 0.8, 0.9])
# Out:
# count    18207.000000
# mean        25.122206
# std          4.669943
# min         16.000000
# 10%         19.000000
# 20%         21.000000
# 50%         25.000000
# 80%         29.000000
# 90%         32.000000
# max         45.000000
# Name: Age, dtype: float64

# %%
df.agg({'Age':['min', 'max', 'skew', 'median'],
        'Overall':['mean', 'max']})
# Out:
#               Age    Overall
# min     16.000000        NaN
# max     45.000000  94.000000
# skew     0.391764        NaN
# median  25.000000        NaN
# mean          NaN  66.238699

# %%
df.groupby('Nationality')['Age', 'Overall'].mean().sort_values(by='Overall', ascending=False)
# Out:
# <ipython-input-157-08ae671e58f2>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Nationality')['Age', 'Overall'].mean().sort_values(by='Overall', ascending=False)
#                             Age    Overall
# Nationality
# United Arab Emirates  26.000000  77.000000
# Central African Rep.  25.666667  73.333333
# Israel                28.214286  72.142857
# Dominican Republic    23.000000  72.000000
# São Tomé & Príncipe   31.000000  72.000000
# ...                         ...        ...
# South Sudan           25.000000  60.000000
# China PR              26.084184  59.910714
# India                 24.933333  58.666667
# Botswana              20.000000  56.000000
# Indonesia             17.000000  56.000000
#
# [164 rows x 2 columns]

# %%
df.Nationality.value_counts()
# Out:
# England                 1662
# Germany                 1198
# Spain                   1072
# Argentina                937
# France                   914
#                         ...
# Puerto Rico                1
# South Sudan                1
# Botswana                   1
# Oman                       1
# United Arab Emirates       1
# Name: Nationality, Length: 164, dtype: int64

# %%
df.Nationality.value_counts(normalize= True)
# Out:
# England                 0.091284
# Germany                 0.065799
# Spain                   0.058878
# Argentina               0.051464
# France                  0.050200
#                           ...
# Puerto Rico             0.000055
# South Sudan             0.000055
# Botswana                0.000055
# Oman                    0.000055
# United Arab Emirates    0.000055
# Name: Nationality, Length: 164, dtype: float64
