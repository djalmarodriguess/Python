# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('kc_house_data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])
df.dtypes
# Out:
# id                        int64
# date             datetime64[ns]
# price                   float64
# bedrooms                  int64
# bathrooms               float64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# waterfront                int64
# view                      int64
# condition                 int64
# grade                     int64
# sqft_above                int64
# sqft_basement             int64
# yr_built                  int64
# yr_renovated              int64
# zipcode                   int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# dtype: object

# %%
df['bathrooms'].unique()
# Out:
# array([1.  , 2.25, 3.  , 2.  , 4.5 , 1.5 , 2.5 , 1.75, 2.75, 3.25, 4.  ,
#        3.5 , 0.75, 4.75, 5.  , 4.25, 3.75, 0.  , 1.25, 5.25, 6.  , 0.5 ,
#        5.5 , 6.75, 5.75, 8.  , 7.5 , 7.75, 6.25, 6.5 ])

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
#Data do imóvel mais antigo 
df['date'].sort_values(ascending=True)[0]
# Out:
# Timestamp('2014-10-13 00:00:00')

# %%
#Quantos imóveis possuem o número máximo de andares
maximo = df['floors'].max()
df[df['floors']== maximo].shape[0]
# Out:
# 8

# %%
#Classificação dos imóveis por padrão 
df['level'] = 'standard'
df.loc[df['price'] > 540000,'level'] = 'high_standard'
df.loc[df['price'] < 540000, 'level'] = 'lower_standard'
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...        1180              0
# 1      7242     2.0           0     0  ...        2170            400
# 2     10000     1.0           0     0  ...         770              0
# 3      5000     1.0           0     0  ...        1050            910
# 4      8080     1.0           0     0  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15           level
# 0        5650  lower_standard
# 1        7639  lower_standard
# 2        8062  lower_standard
# 3        5000   high_standard
# 4        7503  lower_standard
#
# [5 rows x 22 columns]

# %%
df[['price', 'id', 'date', 'bedrooms','sqft_lot', 'level']].sort_values('price', ascending = True)
# Out:
#            price          id       date  bedrooms  sqft_lot           level
# 1149     75000.0  3421079032 2015-02-17         1     43377  lower_standard
# 15293    78000.0    40000362 2014-05-06         2     16344  lower_standard
# 465      80000.0  8658300340 2014-05-23         1      5050  lower_standard
# 16198    81000.0  3028200080 2015-03-24         2      9975  lower_standard
# 8274     82000.0  3883800011 2014-11-05         3     10426  lower_standard
# ...          ...         ...        ...       ...       ...             ...
# 1448   5350000.0  8907500070 2015-04-13         5     23985   high_standard
# 4411   5570000.0  2470100110 2014-08-04         5     35069   high_standard
# 9254   6885000.0  9208900037 2014-09-19         6     31374   high_standard
# 3914   7062500.0  9808700762 2014-06-11         5     37325   high_standard
# 7252   7700000.0  6762700020 2014-10-13         6     27600   high_standard
#
# [21613 rows x 6 columns]

# %%
df.shape
# Out:
# (21613, 22)

# %%
df.loc[df['date'] >= '2014-01-01', 'house_age'] = 'new_house'
df.loc[df['date'] <= '2014-01-01', 'house_age'] = 'old_house'
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 0      5650     1.0           0     0  ...              0      1955
# 1      7242     2.0           0     0  ...            400      1951
# 2     10000     1.0           0     0  ...              0      1933
# 3      5000     1.0           0     0  ...            910      1965
# 4      8080     1.0           0     0  ...              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503
#
#             level  house_age
# 0  lower_standard  new_house
# 1  lower_standard  new_house
# 2  lower_standard  new_house
# 3   high_standard  new_house
# 4  lower_standard  new_house
#
# [5 rows x 23 columns]

# %%
df['bedrooms'].unique()
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  0,  8,  9, 11, 10, 33], dtype=int64)

# %%
df.loc[df['bedrooms'] == 1, 'dormitory_type'] = 'studio'
df.loc[df['bedrooms']== 2, 'dormitory_type'] = 'apartament'
df.loc[df['bedrooms'] > 2, 'dormitory_type'] = 'house'
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  yr_built  yr_renovated  zipcode  \
# 0      5650     1.0           0     0  ...      1955             0    98178
# 1      7242     2.0           0     0  ...      1951          1991    98125
# 2     10000     1.0           0     0  ...      1933             0    98028
# 3      5000     1.0           0     0  ...      1965             0    98136
# 4      8080     1.0           0     0  ...      1987             0    98074
#
#        lat     long  sqft_living15  sqft_lot15           level  house_age  \
# 0  47.5112 -122.257           1340        5650  lower_standard  new_house
# 1  47.7210 -122.319           1690        7639  lower_standard  new_house
# 2  47.7379 -122.233           2720        8062  lower_standard  new_house
# 3  47.5208 -122.393           1360        5000   high_standard  new_house
# 4  47.6168 -122.045           1800        7503  lower_standard  new_house
#
#    dormitory_type
# 0           house
# 1           house
# 2      apartament
# 3           house
# 4           house
#
# [5 rows x 24 columns]

# %%
plt.figure(figsize =(10,8) )
df.groupby('dormitory_type')['id'].count().plot.bar()
# Out:
# <AxesSubplot:xlabel='dormitory_type'>

# %%
df['condition'].unique()
# Out:
# array([3, 5, 4, 1, 2], dtype=int64)

# %%
df.loc[df['condition'] <= 2, 'condition_type'] = 'bad'
df.loc[(df['condition'] == 3 ) | (df['condition'] == 4), 'condition_type' ] = 'regular'
df.loc[df['condition'] == 5, 'condition_type'] = 'good'
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  yr_renovated  zipcode      lat  \
# 0      5650     1.0           0     0  ...             0    98178  47.5112
# 1      7242     2.0           0     0  ...          1991    98125  47.7210
# 2     10000     1.0           0     0  ...             0    98028  47.7379
# 3      5000     1.0           0     0  ...             0    98136  47.5208
# 4      8080     1.0           0     0  ...             0    98074  47.6168
#
#       long  sqft_living15  sqft_lot15           level  house_age  \
# 0 -122.257           1340        5650  lower_standard  new_house
# 1 -122.319           1690        7639  lower_standard  new_house
# 2 -122.233           2720        8062  lower_standard  new_house
# 3 -122.393           1360        5000   high_standard  new_house
# 4 -122.045           1800        7503  lower_standard  new_house
#
#    dormitory_type  condition_type
# 0           house         regular
# 1           house         regular
# 2      apartament         regular
# 3           house            good
# 4           house         regular
#
# [5 rows x 25 columns]

# %%
df.groupby('condition_type')['id'].count().plot.bar()
# Out:
# <AxesSubplot:xlabel='condition_type'>

# %%
df.dtypes
# Out:
# id                         int64
# date              datetime64[ns]
# price                    float64
# bedrooms                   int64
# bathrooms                float64
# sqft_living                int64
# sqft_lot                   int64
# floors                   float64
# waterfront                 int64
# view                       int64
# condition                  int64
# grade                      int64
# sqft_above                 int64
# sqft_basement              int64
# yr_built                   int64
# yr_renovated               int64
# zipcode                    int64
# lat                      float64
# long                     float64
# sqft_living15              int64
# sqft_lot15                 int64
# level                     object
# house_age                 object
# dormitory_type            object
# condition_type            object
# dtype: object

# %%
df['condition'] = df['condition'].astype(str)
df.dtypes
# Out:
# id                         int64
# date              datetime64[ns]
# price                    float64
# bedrooms                   int64
# bathrooms                float64
# sqft_living                int64
# sqft_lot                   int64
# floors                   float64
# waterfront                 int64
# view                       int64
# condition                 object
# grade                      int64
# sqft_above                 int64
# sqft_basement              int64
# yr_built                   int64
# yr_renovated               int64
# zipcode                    int64
# lat                      float64
# long                     float64
# sqft_living15              int64
# sqft_lot15                 int64
# level                     object
# house_age                 object
# dormitory_type            object
# condition_type            object
# dtype: object

# %%
#Remover colunas
df = df.drop(columns = ['sqft_lot15', 'sqft_living15'])

# %%
df.shape
# Out:
# (21613, 23)

# %%
df.dtypes
# Out:
# id                         int64
# date              datetime64[ns]
# price                    float64
# bedrooms                   int64
# bathrooms                float64
# sqft_living                int64
# sqft_lot                   int64
# floors                   float64
# waterfront                 int64
# view                       int64
# condition                 object
# grade                      int64
# sqft_above                 int64
# sqft_basement              int64
# yr_built                   int64
# yr_renovated               int64
# zipcode                    int64
# lat                      float64
# long                     float64
# level                     object
# house_age                 object
# dormitory_type            object
# condition_type            object
# dtype: object

# %%
#Modificar o tipo para data
df['yr_built'] = pd.to_datetime(df['yr_built'])
df.dtypes
# Out:
# id                         int64
# date              datetime64[ns]
# price                    float64
# bedrooms                   int64
# bathrooms                float64
# sqft_living                int64
# sqft_lot                   int64
# floors                   float64
# waterfront                 int64
# view                       int64
# condition                 object
# grade                      int64
# sqft_above                 int64
# sqft_basement              int64
# yr_built          datetime64[ns]
# yr_renovated               int64
# zipcode                    int64
# lat                      float64
# long                     float64
# level                     object
# house_age                 object
# dormitory_type            object
# condition_type            object
# dtype: object

# %%
df['yr_renovated'] = pd.to_datetime(df['yr_renovated'])         
df.dtypes
# Out:
# id                         int64
# date              datetime64[ns]
# price                    float64
# bedrooms                   int64
# bathrooms                float64
# sqft_living                int64
# sqft_lot                   int64
# floors                   float64
# waterfront                 int64
# view                       int64
# condition                 object
# grade                      int64
# sqft_above                 int64
# sqft_basement              int64
# yr_built          datetime64[ns]
# yr_renovated      datetime64[ns]
# zipcode                    int64
# lat                      float64
# long                     float64
# level                     object
# house_age                 object
# dormitory_type            object
# condition_type            object
# dtype: object

# %%
#Data mais antiga de um imóvel construido
df['yr_built'].sort_values(ascending=True)
# Out:
# 4697    1970-01-01 00:00:00.000001900
# 2961    1970-01-01 00:00:00.000001900
# 12369   1970-01-01 00:00:00.000001900
# 15016   1970-01-01 00:00:00.000001900
# 5236    1970-01-01 00:00:00.000001900
#                      ...
# 21270   1970-01-01 00:00:00.000002015
# 17098   1970-01-01 00:00:00.000002015
# 7526    1970-01-01 00:00:00.000002015
# 20086   1970-01-01 00:00:00.000002015
# 14489   1970-01-01 00:00:00.000002015
# Name: yr_built, Length: 21613, dtype: datetime64[ns]

# %%
df['yr_built']
# Out:
# 0       1970-01-01 00:00:00.000001955
# 1       1970-01-01 00:00:00.000001951
# 2       1970-01-01 00:00:00.000001933
# 3       1970-01-01 00:00:00.000001965
# 4       1970-01-01 00:00:00.000001987
#                      ...
# 21608   1970-01-01 00:00:00.000002009
# 21609   1970-01-01 00:00:00.000002014
# 21610   1970-01-01 00:00:00.000002009
# 21611   1970-01-01 00:00:00.000002004
# 21612   1970-01-01 00:00:00.000002008
# Name: yr_built, Length: 21613, dtype: datetime64[ns]

# %%
#Imóveis com 2 andares
df[df['floors'] ==2].count()[0]
# Out:
# 8241

# %%
#Imóveis classificados como regular
df.groupby('condition_type')['id'].count()[2]
# Out:
# 19710

# %%
df.groupby('waterfront')['id'].count()
# Out:
# waterfront
# 0    21450
# 1      163
# Name: id, dtype: int64

# %%
df.groupby('condition_type')['waterfront'].count()
# Out:
# condition_type
# bad          202
# good        1701
# regular    19710
# Name: waterfront, dtype: int64

# %%
#Imóveis com bad condition e com vista para o mar.
df.loc[(df['condition_type'] == 'bad') & (df['waterfront'] == 1)]
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 11225  6613000935 2014-05-13  2555000.0         4        2.5         5300
# 15371  7936500221 2015-01-14   658000.0         2        1.0         1010
#
#        sqft_lot  floors  waterfront  view  ... sqft_basement  \
# 11225     26211     2.0           1     2  ...           730
# 15371     14244     1.0           1     4  ...             0
#
#                            yr_built  yr_renovated  zipcode      lat     long  \
# 11225 1970-01-01 00:00:00.000001923    1970-01-01    98105  47.6610 -122.269
# 15371 1970-01-01 00:00:00.000001926    1970-01-01    98136  47.5476 -122.399
#
#                level  house_age  dormitory_type condition_type
# 11225  high_standard  new_house           house            bad
# 15371  high_standard  new_house      apartament            bad
#
# [2 rows x 23 columns]

# %%
#Imóveis com boas condições(condition_type =good) e sao casas novas(house_age = new_house)
df[(df['condition_type'] == 'good') & (df['house_age'] == 'new_house')]
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 3      2487200875 2014-12-09   604000.0         4       3.00         1960
# 25     1202000200 2014-11-03   233000.0         3       2.00         1710
# 27     3303700376 2014-12-01   667000.0         3       1.00         1400
# 49      822039084 2015-03-11  1350000.0         3       2.50         2753
# 62     5072410070 2014-10-21   505000.0         3       1.75         2519
# ...           ...        ...        ...       ...        ...          ...
# 19604  7518504130 2014-06-26   663000.0         3       2.00         1480
# 19620  3902100175 2014-07-28   850000.0         5       3.00         3900
# 19873  3449000060 2014-10-01   320000.0         3       1.00         1400
# 19905  2888000030 2014-09-26   500000.0         4       2.25         2270
# 21303   522059130 2015-04-29   465000.0         3       1.00         1150
#
#        sqft_lot  floors  waterfront  view  ... sqft_basement  \
# 3          5000     1.0           0     0  ...           910
# 25         4697     1.5           0     0  ...             0
# 27         1581     1.5           0     0  ...             0
# 49        65005     1.0           1     2  ...           588
# 62         8690     2.0           0     0  ...             0
# ...         ...     ...         ...   ...  ...           ...
# 19604      3876     1.0           0     0  ...           620
# 19620      5250     1.5           0     1  ...          1280
# 19873      9000     1.0           0     0  ...             0
# 19905      8196     1.0           0     0  ...          1120
# 21303     18200     1.0           0     0  ...             0
#
#                            yr_built  yr_renovated  zipcode      lat     long  \
# 3     1970-01-01 00:00:00.000001965    1970-01-01    98136  47.5208 -122.393
# 25    1970-01-01 00:00:00.000001941    1970-01-01    98002  47.3048 -122.218
# 27    1970-01-01 00:00:00.000001909    1970-01-01    98112  47.6221 -122.314
# 49    1970-01-01 00:00:00.000001953    1970-01-01    98070  47.4041 -122.451
# 62    1970-01-01 00:00:00.000001973    1970-01-01    98166  47.4428 -122.344
# ...                             ...           ...      ...      ...      ...
# 19604 1970-01-01 00:00:00.000001928    1970-01-01    98117  47.6808 -122.382
# 19620 1970-01-01 00:00:00.000001931    1970-01-01    98116  47.5577 -122.389
# 19873 1970-01-01 00:00:00.000001959    1970-01-01    98059  47.5022 -122.145
# 19905 1970-01-01 00:00:00.000001963    1970-01-01    98034  47.7214 -122.227
# 21303 1970-01-01 00:00:00.000001959    1970-01-01    98058  47.4262 -122.187
#
#                 level  house_age  dormitory_type condition_type
# 3       high_standard  new_house           house           good
# 25     lower_standard  new_house           house           good
# 27      high_standard  new_house           house           good
# 49      high_standard  new_house           house           good
# 62     lower_standard  new_house           house           good
# ...               ...        ...             ...            ...
# 19604   high_standard  new_house           house           good
# 19620   high_standard  new_house           house           good
# 19873  lower_standard  new_house           house           good
# 19905  lower_standard  new_house           house           good
# 21303  lower_standard  new_house           house           good
#
# [1701 rows x 23 columns]

# %%
df['dormitory_type'].unique()
# Out:
# array(['house', 'apartament', 'studio', nan], dtype=object)

# %%
#Valor do Imóvel mais caro registrado como 'studio' 
df.groupby('dormitory_type')['price'].max()[2]
# Out:
# 1247000.0

# %%
# Maior número de quartos que o imóvel do tipo 'house' possui.
df.groupby('dormitory_type')['bedrooms'].max()[1]
# Out:
# 33

# %%
df[['bedrooms', 'dormitory_type', 'id']].sort_values('bedrooms', ascending = False)
# Out:
#        bedrooms dormitory_type          id
# 15870        33          house  2402100895
# 8757         11          house  1773100755
# 15161        10          house  5566100170
# 13314        10          house   627300145
# 19254        10          house  8812401450
# ...         ...            ...         ...
# 19452         0            NaN  3980300371
# 8484          0            NaN  2310060040
# 875           0            NaN  6306400140
# 8477          0            NaN  2569500210
# 9773          0            NaN  3374500520
#
# [21613 rows x 3 columns]

# %%
#Quantidade de imóveis com o número máximo de quartos
df[df['bedrooms'] == 33]
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 15870  2402100895 2014-06-25  640000.0        33       1.75         1620
#
#        sqft_lot  floors  waterfront  view  ... sqft_basement  \
# 15870      6000     1.0           0     0  ...           580
#
#                            yr_built  yr_renovated  zipcode      lat     long  \
# 15870 1970-01-01 00:00:00.000001947    1970-01-01    98103  47.6878 -122.331
#
#                level  house_age  dormitory_type condition_type
# 15870  high_standard  new_house           house           good
#
# [1 rows x 23 columns]
