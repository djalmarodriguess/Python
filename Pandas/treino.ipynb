# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv', sep = ',')

# %%
df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
#Trocar tipo da data
#df = pd.read_csv('train.csv', parse_dates=[0]) = pode ser assim também, chamando a função 'parse_dates'
df['datetime'] = pd.to_datetime(df['datetime'])

# %%
df.dtypes
# Out:
# datetime      datetime64[ns]
# season                 int64
# holiday                int64
# workingday             int64
# weather                int64
# temp                 float64
# atemp                float64
# humidity               int64
# windspeed            float64
# casual                 int64
# registered             int64
# count                  int64
# dtype: object

# %%
#Cria coluna 'Dia'
df['day'] = df['datetime'].dt.day
df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  day
# 0        81        0.0       3          13     16    1
# 1        80        0.0       8          32     40    1
# 2        80        0.0       5          27     32    1
# 3        75        0.0       3          10     13    1
# 4        75        0.0       0           1      1    1

# %%
#Coluna 'Mês'
df['month'] = df['datetime'].dt.month
df.head()

# %%
#Coluna 'Ano'
df['year'] = df['datetime'].dt.year
df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  day  month  year
# 0        81        0.0       3          13     16    1      1  2011
# 1        80        0.0       8          32     40    1      1  2011
# 2        80        0.0       5          27     32    1      1  2011
# 3        75        0.0       3          10     13    1      1  2011
# 4        75        0.0       0           1      1    1      1  2011

# %%
df[['day', 'month', 'year']]
# Out:
#        day  month  year
# 0        1      1  2011
# 1        1      1  2011
# 2        1      1  2011
# 3        1      1  2011
# 4        1      1  2011
# ...    ...    ...   ...
# 10881   19     12  2012
# 10882   19     12  2012
# 10883   19     12  2012
# 10884   19     12  2012
# 10885   19     12  2012
#
# [10886 rows x 3 columns]

# %%
# Apagar coluna
df = df.drop(columns= ['Year'])
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-c7fb2eb20edb> in <module>
#       1 # Apagar coluna
# ----> 2 df = df.drop(columns= ['Year'])
#       3 df.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['Year'] not found in axis"

# %%
data = df['day'].map(str) + '-' + df['month'].map(str)
print(data)
# Out:
# 0          1-1
# 1          1-1
# 2          1-1
# 3          1-1
# 4          1-1
#          ...
# 10881    19-12
# 10882    19-12
# 10883    19-12
# 10884    19-12
# 10885    19-12
# Length: 10886, dtype: object

# %%
#Concatenar colunas
df['date'] = df['day'].map(str) + '/' + df['month'].map(str) + '/' + df['year'].map(str)
df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  day  month  year      date
# 0        81        0.0       3          13     16    1      1  2011  1/1/2011
# 1        80        0.0       8          32     40    1      1  2011  1/1/2011
# 2        80        0.0       5          27     32    1      1  2011  1/1/2011
# 3        75        0.0       3          10     13    1      1  2011  1/1/2011
# 4        75        0.0       0           1      1    1      1  2011  1/1/2011

# %%
df.dtypes

# %%
df['date'] = pd.to_datetime(df['date'])
df.dtypes
# Out:
# datetime      datetime64[ns]
# season                 int64
# holiday                int64
# workingday             int64
# weather                int64
# temp                 float64
# atemp                float64
# humidity               int64
# windspeed            float64
# casual                 int64
# registered             int64
# count                  int64
# day                    int64
# month                  int64
# year                   int64
# date          datetime64[ns]
# dtype: object

# %%
df[df['date'].dt.month == 2]

# %%
df[(df['date'].dt.month == 2 ) & (df['temp'] > 14)]

# %%
df[(df['temp'] < 15) & (df['humidity'] >= 88)].shape, df[(df['count'] >= 50) | (df['windspeed'] > 13)].shape
# Out:
# ((264, 16), (8873, 16))

# %%
df[['temp','atemp']]
# Out:
#         temp   atemp
# 0       9.84  14.395
# 1       9.02  13.635
# 2       9.02  13.635
# 3       9.84  14.395
# 4       9.84  14.395
# ...      ...     ...
# 10881  15.58  19.695
# 10882  14.76  17.425
# 10883  13.94  15.910
# 10884  13.94  17.425
# 10885  13.12  16.665
#
# [10886 rows x 2 columns]

# %%
#Valor maximo em cada coluna
df.nunique()

# %%
df.value_counts()

# %%
df.head()

# %%
df.columns

# %%
df.index

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  datetime64[ns]
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
#  12  day         10886 non-null  int64
#  13  month       10886 non-null  int64
#  14  year        10886 non-null  int64
#  15  date        10886 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(3), int64(11)
# memory usage: 1.3 MB

# %%
df.values

# %%
df.axes

# %%
df.columns

# %%
df.tail()

# %%
#Amostragem de linhas aleatorias
df.sample(10)
# Out:
#                 datetime  season  holiday  workingday  weather   temp   atemp  \
# 7709 2012-06-01 14:00:00       2        0           1        3  29.52  34.090
# 9950 2012-10-18 23:00:00       4        0           1        2  22.14  25.760
# 5595 2012-01-08 06:00:00       1        0           0        2  12.30  16.665
# 3247 2011-08-05 05:00:00       3        0           1        1  26.24  29.545
# 394  2011-01-17 22:00:00       1        1           0        3   5.74   6.060
# 1018 2011-03-06 22:00:00       1        0           0        2   9.02   9.850
# 2013 2011-05-10 19:00:00       2        0           1        1  24.60  31.060
# 3910 2011-09-13 23:00:00       3        0           1        1  26.24  29.545
# 7367 2012-05-06 08:00:00       2        0           0        2  20.50  24.240
# 8346 2012-07-09 03:00:00       3        0           1        3  28.70  33.335
#
#       humidity  windspeed  casual  registered  count  day  month  year  \
# 7709        66    19.0012      55         199    254    1      6  2012
# 9950        83     0.0000       6         111    117   18     10  2012
# 5595        52     0.0000       0           2      2    8      1  2012
# 3247        78     6.0032       0          16     16    5      8  2011
# 394         93    16.9979       0          13     13   17      1  2011
# 1018       100    26.0027       0          10     10    6      3  2011
# 2013        43    15.0013      69         365    434   10      5  2011
# 3910        78     7.0015      15          59     74   13      9  2011
# 7367        88     8.9981      23          91    114    6      5  2012
# 8346        89    12.9980       0           5      5    9      7  2012
#
#            date
# 7709 2012-01-06
# 9950 2012-10-18
# 5595 2012-08-01
# 3247 2011-05-08
# 394  2011-01-17
# 1018 2011-06-03
# 2013 2011-10-05
# 3910 2011-09-13
# 7367 2012-06-05
# 8346 2012-09-07

# %%
df.ndim
# Out:
# 2

# %%
df.size

# %%
df.info()

# %%
df.shape

# %%
df.describe()

# %%
df['temp'].describe()
# Out:
# count    10886.00000
# mean        20.23086
# std          7.79159
# min          0.82000
# 25%         13.94000
# 50%         20.50000
# 75%         26.24000
# max         41.00000
# Name: temp, dtype: float64

# %%
media = df[df['temp'] > df['temp'].mean()]
media
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 746   2011-02-14 11:00:00       1        0           1        1  21.32
# 747   2011-02-14 12:00:00       1        0           1        1  22.96
# 748   2011-02-14 13:00:00       1        0           1        1  23.78
# 749   2011-02-14 14:00:00       1        0           1        1  24.60
# 750   2011-02-14 15:00:00       1        0           1        1  22.96
# ...                   ...     ...      ...         ...      ...    ...
# 10661 2012-12-10 15:00:00       4        0           1        2  20.50
# 10662 2012-12-10 16:00:00       4        0           1        2  20.50
# 10665 2012-12-10 19:00:00       4        0           1        1  21.32
# 10668 2012-12-10 22:00:00       4        0           1        2  20.50
# 10851 2012-12-18 13:00:00       4        0           1        1  20.50
#
#         atemp  humidity  windspeed  casual  registered  count  day  month  \
# 746    25.000        23    16.9979      10          43     53   14      2
# 747    26.515        22    30.0026      27          99    126   14      2
# 748    27.275        19    26.0027      27          93    120   14      2
# 749    29.545        15    32.9975      14          76     90   14      2
# 750    26.515        21    43.9989      19          71     90   14      2
# ...       ...       ...        ...     ...         ...    ...  ...    ...
# 10661  24.240        87    11.0014      29         207    236   10     12
# 10662  24.240        88     7.0015      37         308    345   10     12
# 10665  25.000        77    19.0012      18         409    427   10     12
# 10668  24.240        82    15.0013      11         115    126   10     12
# 10851  24.240        42    19.0012      51         235    286   18     12
#
#        year       date
# 746    2011 2011-02-14
# 747    2011 2011-02-14
# 748    2011 2011-02-14
# 749    2011 2011-02-14
# 750    2011 2011-02-14
# ...     ...        ...
# 10661  2012 2012-10-12
# 10662  2012 2012-10-12
# 10665  2012 2012-10-12
# 10668  2012 2012-10-12
# 10851  2012 2012-12-18
#
# [5578 rows x 16 columns]

# %%
df['count'].describe()

# %%
# Função 'quantile()' pega somente o percentil desejado.
maior25 = df[df['count'] > df['count'].quantile(0.25)] 
maior25

# %%
total = df[(df['temp'] > df['temp'].mean()) & (df['count'] > df['count'].quantile(.25))]
total

# %%
df['count'].describe()

# %%
df['temp'].value_counts()

# %%
#'normalize', mostra porcentagem de cada valor contado.
df['temp'].value_counts(normalize = True)

# %%
df['casual'].describe()

# %%
df['casual'].value_counts()

# %%
df['casual'].value_counts(normalize=True)
# Out:
# 0      0.090575
# 1      0.061271
# 2      0.044736
# 3      0.040235
# 4      0.032519
#          ...
# 283    0.000092
# 259    0.000092
# 362    0.000092
# 354    0.000092
# 367    0.000092
# Name: casual, Length: 309, dtype: float64

# %%
df.head()

# %%
df.groupby('year').mean()
# Out:
#         season   holiday  workingday   weather       temp      atemp  \
# year
# 2011  2.511988  0.026558    0.682036  1.426411  19.751988  23.157086
# 2012  2.501281  0.030564    0.679722  1.410505  20.706051  24.149254
#
#        humidity  windspeed    casual  registered       count        day  \
# year
# 2011  63.405017  12.924144  28.73792  115.485430  144.223349   9.982663
# 2012  60.379575  12.675605  43.25000  195.310944  238.560944  10.002379
#
#          month
# year
# 2011  6.538547
# 2012  6.504575

# %%
df['season'].value_counts()
# Out:
# 4    2734
# 2    2733
# 3    2733
# 1    2686
# Name: season, dtype: int64

# %%
df['temp'].hist()
# Out:
# <AxesSubplot:>

# %%
df['temp'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['temp'].describe()
# Out:
# count    10886.00000
# mean        20.23086
# std          7.79159
# min          0.82000
# 25%         13.94000
# 50%         20.50000
# 75%         26.24000
# max         41.00000
# Name: temp, dtype: float64

# %%
df['humidity'].hist()
# Out:
# <AxesSubplot:>

# %%
df['humidity'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['humidity'].describe()
# Out:
# count    10886.000000
# mean        61.886460
# std         19.245033
# min          0.000000
# 25%         47.000000
# 50%         62.000000
# 75%         77.000000
# max        100.000000
# Name: humidity, dtype: float64

# %%
import seaborn as sns

# %%
sns.distplot(df['temp'],bins=10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='temp', ylabel='Density'>

# %%
sns.boxplot(y='temp', data=df )
# Out:
# <AxesSubplot:ylabel='temp'>

# %%
sns.boxplot(y = 'temp', x = 'season', data = df)
# Out:
# <AxesSubplot:xlabel='season', ylabel='temp'>

# %%
sns.violinplot(y= 'temp',data = df)
# Out:
# <AxesSubplot:ylabel='temp'>

# %%
sns.violinplot(y= 'temp', x = 'season', data = df)
# Out:
# <AxesSubplot:xlabel='season', ylabel='temp'>

# %%
sns.violinplot(y= 'temp', x= 'season', data = df, hue = 'weather')
# Out:
# <AxesSubplot:xlabel='season', ylabel='temp'>

# %%
sns.boxplot(y= 'humidity', x= 'weather', data = df)
# Out:
# <AxesSubplot:xlabel='weather', ylabel='humidity'>

# %%
sns.violinplot(y='humidity' , x ='weather' , data= df)
# Out:
# <AxesSubplot:xlabel='weather', ylabel='humidity'>

# %%
df.groupby('workingday')['count'].mean()
# Out:
# workingday
# 0    188.506621
# 1    193.011873
# Name: count, dtype: float64

# %%
df.groupby('workingday')['count'].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='workingday'>

# %%
df.groupby('month')['count'].mean()
# Out:
# month
# 1      90.366516
# 2     110.003330
# 3     148.169811
# 4     184.160616
# 5     219.459430
# 6     242.031798
# 7     235.325658
# 8     234.118421
# 9     233.805281
# 10    227.699232
# 11    193.677278
# 12    175.614035
# Name: count, dtype: float64

# %%
df.groupby('month')['count'].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='month'>

# %%
sns.barplot(y='count' ,x= 'workingday', data= df)
# Out:
# <AxesSubplot:xlabel='workingday', ylabel='count'>

# %%
sns.barplot(y='count' , x= 'season', data= df)
# Out:
# <AxesSubplot:xlabel='season', ylabel='count'>

# %%
df.groupby('season')['count'].mean()
# Out:
# season
# 1    116.343261
# 2    215.251372
# 3    234.417124
# 4    198.988296
# Name: count, dtype: float64

# %%
df['season'].value_counts()
# Out:
# 4    2734
# 2    2733
# 3    2733
# 1    2686
# Name: season, dtype: int64

# %%
df['season'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
sns.barplot(y= 'count', x='season', hue='workingday', data=df)
# Out:
# <AxesSubplot:xlabel='season', ylabel='count'>

# %%
df.groupby('season').mean()
# Out:
#          holiday  workingday   weather       temp      atemp   humidity  \
# season
# 1       0.026433    0.680566  1.424423  12.530491  15.228956  56.297841
# 2       0.017563    0.692645  1.422978  22.823483  26.647098  60.852909
# 3       0.035126    0.675082  1.366630  28.789111  32.540783  64.123674
# 4       0.035113    0.675201  1.459766  16.649239  20.059909  66.173738
#
#         windspeed     casual  registered       count        day      month  \
# season
# 1       14.636978  15.489576  100.853686  116.343261   9.968727   2.006329
# 2       13.405607  47.446762  167.804610  215.251372  10.002195   5.001098
# 3       11.508862  52.220271  182.196853  234.417124  10.001464   7.998902
# 4       11.678147  28.580834  170.407462  198.988296   9.997440  11.000366
#
#                year
# season
# 1       2011.507446
# 2       2011.499817
# 3       2011.500549
# 4       2011.500000

# %%
df['workingday'].dtype
# Out:
# dtype('int64')

# %%
df.head()

# %%
df['workingday'].value_counts()
# Out:
# 1    7412
# 0    3474
# Name: workingday, dtype: int64

# %%
df['workingday'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
sns.barplot(y= 'casual', x='weather', data= df)
# Out:
# <AxesSubplot:xlabel='weather', ylabel='casual'>

# %%
df.groupby('weather').mean()
# Out:
#            season   holiday  workingday       temp      atemp   humidity  \
# weather
# 1        2.497080  0.028365    0.672831  20.557122  23.994126  56.716769
# 2        2.530346  0.032463    0.683486  19.614608  23.072414  69.100565
# 3        2.509895  0.017462    0.739232  19.546356  22.753091  81.341094
# 4        1.000000  0.000000    1.000000   8.200000  11.365000  86.000000
#
#          windspeed     casual  registered       count        day     month  \
# weather
# 1        12.892542  40.308676  164.928115  205.236791   9.991379  6.479283
# 2        12.179905  30.785462  148.170078  178.955540  10.103387  6.631969
# 3        14.071248  17.442375  101.403958  118.846333   9.637951  6.516880
# 4         6.003200   6.000000  158.000000  164.000000   9.000000  1.000000
#
#                 year
# weather
# 1        2011.501808
# 2        2011.517996
# 3        2011.449360
# 4        2012.000000

# %%
df.groupby('month')['count'].describe()
# Out:
#        count        mean         std  min    25%    50%     75%    max
# month
# 1      884.0   90.366516   95.302518  1.0  20.00   65.0  123.00  512.0
# 2      901.0  110.003330  109.802322  1.0  26.00   78.0  157.00  539.0
# 3      901.0  148.169811  155.352814  1.0  26.00  100.0  219.00  801.0
# 4      909.0  184.160616  182.417619  1.0  35.00  133.0  277.00  822.0
# 5      912.0  219.459430  189.320173  1.0  56.00  182.0  323.50  873.0
# 6      912.0  242.031798  199.628690  1.0  73.75  206.0  363.00  869.0
# 7      912.0  235.325658  184.857337  1.0  77.25  209.5  358.50  872.0
# 8      912.0  234.118421  197.198461  1.0  67.75  193.0  337.25  897.0
# 9      909.0  233.805281  208.915910  1.0  58.00  188.0  349.00  977.0
# 10     911.0  227.699232  204.079411  1.0  57.00  180.0  342.00  948.0
# 11     911.0  193.677278  165.420965  1.0  53.50  162.0  284.00  724.0
# 12     912.0  175.614035  155.926050  1.0  45.00  138.0  257.00  759.0

# %%
df['count'].describe()['50%']
# Out:
# 145.0

# %%
df.groupby('month')['count'].describe()['50%'].plot()
# Out:
# <AxesSubplot:xlabel='month'>

# %%
df.groupby('month')['count'].describe()['mean'].sort_index(ascending=False).plot()

# %%
df.groupby('month')['count'].describe()['max'].plot()
# Out:
# <AxesSubplot:xlabel='month'>

# %%
df.groupby('month')['count'].describe()['min'].plot()
# Out:
# <AxesSubplot:xlabel='month'>

# %%
df.groupby('month')['count'].describe()['count']
# Out:
# month
# 1     884.0
# 2     901.0
# 3     901.0
# 4     909.0
# 5     912.0
# 6     912.0
# 7     912.0
# 8     912.0
# 9     909.0
# 10    911.0
# 11    911.0
# 12    912.0
# Name: count, dtype: float64

# %% [markdown]
# Variáveis Contínuas

# %%
sns.pairplot(x_vars= 'temp', y_vars= 'count', data= df, size= 7)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(x_vars= 'temp', y_vars= 'count', hue= 'season',data= df, size= 7)

# %%
sns.pairplot(x_vars= 'humidity', y_vars= 'count',size= 10,hue= 'season' , data = df, kind= 'reg')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(x_vars= 'temp', y_vars= 'casual',size= 7,hue= 'holiday' , data = df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(x_vars= 'temp', y_vars= 'casual',size= 7,hue= 'holiday' , data = df, kind= 'reg')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
